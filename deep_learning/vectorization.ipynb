# %% [markdown]
# # setting up importing

# %% [markdown]
# ### This code explain the difference between make the dot product
# ### for w and x for deep learning using #vectorization vs #for loop explicit in the code

# %%
import numpy as np
import time

# %%
a = np.random.rand(1000000)
b = np.random.rand(1000000)
tic = time.time()
c = np.dot(a,b)
toc = time.time()
time1 = toc - tic
print(c)
print("vectorization proccess took time "+str(1000*(time1))+" ms")


print("=====================================")
z = 0
i = 0
tic = time.time()
for i in range (1000000):
    z += a[i] * b[i]
toc = time.time()
time2 = toc - tic
print(z)
print("for loop took time "+str(1000*(time2))+" ms")
print(time2/time1)
# Out:
# 250108.22227201777
# vectorization proccess took time 1.1570453643798828 ms
# ...
# 250108.2222720242
# for loop took time 488.68680000305176 ms
# 422.3575108180507
